# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import requests

# %%
api_data=requests.get("https://api.cryptonator.com/api/full/btc-usd").json()

# %%
mkt_data=api_data["ticker"]["markets"]

# %%
df=pd.DataFrame(mkt_data)
markets=df["market"]

# %%
print(df)
# Out:
#       market          price        volume
# 0   BitFinex  6660.00000000  52585.725478
# 1   Bitstamp  6671.54000000  10677.073689
# 2    Bittrex  6665.00000000   2770.589582
# 3      C-Cex  7260.00000000      3.134571
# 4     Cex.io  6816.90000000    851.015665
# 5       Exmo  6946.39000000   1043.675152
# 6     Hitbtc  6987.06000000   6109.070000
# 7     Kraken  6648.50000000   7227.339477
# 8   Livecoin  7084.40002000   1566.206059
# 9   Poloniex  6656.24800776   2478.295546
# 10     wexnz  6931.37900000    924.153640
# 11     YoBit  7140.00000000    142.123337

# %%
price = df["price"]

# %%
np_price=np.array(price)

# %%
volume = df["volume"]

# %%
np_volume=np.array(volume)

# %%
max_price=np.max(np_price)

# %%
min_price=np.min(np_price)

# %%
max_mkt = np.argmax(np_price)

# %%
min_mkt = np.argmin(np_price)

# %%
print(markets[max_mkt])
# Out:
# C-Cex

# %%
difference = float(max_price)-float(min_price)

# %%
print("market", markets[max_mkt], "has max price" +str(max_price))
# Out:
# market C-Cex has max price7260.00000000

# %%
print("market", markets[min_mkt], "has min price" +str(min_price))
# Out:
# market Kraken has min price6648.50000000

# %%
print("differnce in price is: ", difference)
# Out:
# differnce in price is:  611.5

# %%
plt.figure(figsize=(20,10))
plt.scatter(price,volume)
plt.ylabel("volume")
plt.ylabel("price")
for i in (markets.index):
    plt.annotate(markets[i],xy=(price[i],volume[i]),xytext=(price[i],volume[i]))
